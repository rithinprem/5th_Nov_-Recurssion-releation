# %% [raw]
# 1)  Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.
#
# Ans:
#
# Given,
# T(n) = 3T(n-1)+12n
# T(0) = 5
# let n= 0
# so,  T(0) =3T(-1) = 5
#
# let n=2
# T(2) = 3T(1)+12*2 = 3T(1)+24  -----(1)
#
# let n=1
# T(1) = 3T(0)+12
# putting T(0) value in it
# T(1) = 3*5+12 = 27
#
# putting T(1) in equation (1)
#  so, T(2) = 3*27+24 = 105
#
# so answer for T(2) is 105

# %% [raw]
# 2) Given a recurrence relation,solve it using th substitution method
#
# a) T(n) = T(n-1)+c
#
# Ans:
#
# Given,
# T(n) = T(n-1)+c
# then T(n-1) = T(n-2)+c
# so, T(n) = T(n-2)+2c
#
# T(n-2) = T(n-3)+c
# so, T(n) = T(n-3)+3c
#
# In general:
# T(n) = T(n-k)+kc
#
# At base condition:
# T(0) => n=k
#
# so, T(n)=T(0)+nc  ans.
#
#
#
# b) T(n) = 2T(n/2)+n
#
# Ans:
#
# Given,
# T(n) = 2T(n/2)+n
#
# T(n/2) = 2T(n/4)+n/2
#
# So, T(n) = 2(2T(n/4)+n/2) + n
#
# T(n/4) = 2T(n/8)+n/4
#
# So, T(n) = 2(2(2T(n/8)+n/4)+n/2)+n
#
# In general,
#
# T(n) = 2**k T(n/2**k)+kn
#
# At base case,
# T(1) => n=2**k => k=log(base2)n
#
# So, T(n) = nT(1) + nlog(base2)n              ans.
#
#
#
# C) T(n) = 2T(n/2)+c
# Ans:
#
# Given,
# T(n) = 2T(n/2)+c
#
# T(n/2) = 2T(n/4)+c
# so, T(n) = 2(2T(n/4)+c)+c = 4T(n/4)+3c
#
# In general,
# T(n) = 2**k T(n/2**k) + (2**k -1)c
#
# At base case,
# T(1) => n=2**k => k = log(base2)n
#
# So, T(n) = nT(1) + (n-1)c             ans.
#
#
#
# d) T(n) = T(n/2)+c
#
# Ans:
# Given,
# T(n) = T(n/2)+c
#
# T(n/2) = T(n/4)+c
# so, T(n) = T(n/4)+2c
#
# In general T(n) = T(n/2**k)+kc
#
# At base case,
# T(1) = n = 2**k => k = log(base2)n
#
# So,
# T(n) = T(1)+ (log(base2)n)c          ans.

# %% [raw]
# 3) Given a recurrence relation,solve it using  the recursive tree approach
#
# a) T(n) = 2T(n-1)+1
#
# Ans:
#
#                 n           cost=1
#                / \
#            n-1     n-1       cost=2
#           / \       / \
#         n-2  n-2   n-2  n-2   cost=4
#
#
# LHS of tree:
# n -> n-1 ->n-2---- ...->n-k
#
# At base case,
# n=k
#
# Total cost = 1+2+4+8..2**k
# => It is GP series
#
# Total cost = 2**(k-1) = 2**(n-1)
#
# Time complexity = O(2**n)   ans.
#
#
#
#
# b) T(n) = 2T(n/2) +n
#
# Ans:
#
#                 n                cost = n
#               /   \
#           n/2       n/2          cost = n
#          /  \        /  \
#        n/4  n/4     n/4  n/4     cost = n
#
#
# LHS:
# n -> n/2 -> n/4 ---...->n/2**k
#
# Total cost = n+n+n+n... = n + kn
#
# At base case n =2**k => k =log(base2)n
#
# So, Total cost = n+nlog(base2)n
#
# Time complexity = O(nlog(base2)n)       ans.
